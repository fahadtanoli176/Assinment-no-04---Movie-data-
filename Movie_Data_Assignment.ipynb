# %% [markdown]
# # **Movie Dataset Python Assignment**

# %% [markdown]
# ### **Question 1**
# Dataset (`movie.csv`) ko pandas mein load karein aur uske pehle 5 rows display karein.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("movie.csv")

# Display first 5 rows
print(df.head())
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# ...

# %% [markdown]
# ### **Question 2**
# Dataset ka total shape (rows aur columns count) check karke print karein.

# %%
rows, columns = df.shape

# Print rows and columns
print("Total Rows:", rows)
print("Total Columns:", columns)
# Out:
# Total Rows: 1000
# Total Columns: 11

# %% [markdown]
# ### **Question 3**
# Check karein ki kis kis column mein missing values (null values) hain aur unka exact count kya hai.

# %%
print(df.isnull().sum())
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ### **Question 4**
# Which movies were released after the year 2000? (Year 2000 ke baad release hone wali movies filter karein).

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# Filter movies after year 2000
movies_after_2000 = df[df['Released_Year'] > 2000]

# Display result
print(movies_after_2000)
# Out:
#                                           Series_Title  Released_Year  \
# 2                                      The Dark Knight         2008.0
# 5        The Lord of the Rings: The Return of the King         2003.0
# 8                                            Inception         2010.0
# 10   The Lord of the Rings: The Fellowship of the Ring         2001.0
# 13               The Lord of the Rings: The Two Towers         2002.0
# ..                                                 ...            ...
# 947              Harry Potter and the Sorcerer's Stone         2001.0
# 948                                         The Others         2001.0
# 949                                               Blow         2001.0
# 950                                 Enemy at the Gates         2001.0
# 951                                    Minority Report         2002.0
#
#     Certificate  Runtime                       Genre  IMDB_Rating  Meta_score  \
# ...

# %% [markdown]
# ### **Question 5**
# Which movies have an IMDB rating greater than 9? (9 se zyada IMDB rating wali movies display karein).

# %%
# Convert IMDB_Rating to numeric
df['IMDB_Rating'] = pd.to_numeric(df['IMDB_Rating'], errors='coerce')


high_rated_movies = df[df['IMDB_Rating'] > 9]

print(high_rated_movies)
# Out:
#                Series_Title  Released_Year Certificate  Runtime         Genre  \
# 0  The Shawshank Redemption         1994.0           A  142 min         Drama
# 1             The Godfather         1972.0           A  175 min  Crime, Drama
#
#    IMDB_Rating  Meta_score              Director          Star1  No_of_Votes  \
# 0          9.3        80.0        Frank Darabont    Tim Robbins      2343110
# 1          9.2       100.0  Francis Ford Coppola  Marlon Brando      1620367
#
#          Gross
# 0   28341469.0
# 1  134966411.0

# %% [markdown]
# ### **Question 6**
# How many movies are there for each genre? (Har genre ki total kitni movies hain, count nikalye).

# %%
# Count total movies in each genre
genre_count = df['Genre'].value_counts()

# Display result
print(genre_count)
# Out:
# Genre
# Drama                        85
# Drama, Romance               37
# Comedy, Drama                35
# Comedy, Drama, Romance       31
# Action, Crime, Drama         30
#                              ..
# Action, Adventure, Family     1
# Action, Crime, Mystery        1
# Animation, Drama, Romance     1
# Drama, War, Western           1
# Adventure, Comedy, War        1
# Name: count, Length: 202, dtype: int64

# %% [markdown]
# ### **Question 7**
# Which movies were directed by Christopher Nolan? (Christopher Nolan ki directed saari movies nikalye).

# %%
# Filter movies directed by Christopher Nolan
nolan_movies = df[df['Director'] == 'Christopher Nolan']

# Display result
print(nolan_movies)
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 2          The Dark Knight         2008.0          UA  152 min
# 8                Inception         2010.0          UA  148 min
# 21            Interstellar         2014.0          UA  169 min
# 36            The Prestige         2006.0           U  130 min
# 63   The Dark Knight Rises         2012.0          UA  164 min
# 69                 Memento         2000.0          UA  113 min
# 155          Batman Begins         2005.0          UA  140 min
# 573                Dunkirk         2017.0          UA  106 min
#
#                          Genre  IMDB_Rating  Meta_score           Director  \
# 2         Action, Crime, Drama          9.0        84.0  Christopher Nolan
# 8    Action, Adventure, Sci-Fi          8.8        74.0  Christopher Nolan
# 21    Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
# 36      Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# ...

# %% [markdown]
# ### **Question 8**
# Which movies have 'Drama' mentioned in their genre? ('Drama' genre wali movies ko filter karein).

# %%
# Filter movies having Drama in genre
drama_movies = df[df['Genre'].str.contains('Drama', na=False)]

# Display result
print(drama_movies)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption         1994.0           A  142 min
# 1               The Godfather         1972.0           A  175 min
# 2             The Dark Knight         2008.0          UA  152 min
# 3      The Godfather: Part II         1974.0           A  202 min
# 4                12 Angry Men         1957.0           U   96 min
# ..                        ...            ...         ...      ...
# 993                    Blowup         1966.0           A  111 min
# 995    Breakfast at Tiffany's         1961.0           A  115 min
# 996                     Giant         1956.0           G  201 min
# 997     From Here to Eternity         1953.0      Passed  118 min
# 998                  Lifeboat         1944.0         NaN   97 min
#
#                         Genre  IMDB_Rating  Meta_score  \
# 0                       Drama          9.3        80.0
# 1                Crime, Drama          9.2       100.0
# ...

# %% [markdown]
# ### **Question 9**
# How can we sort all movies by IMDB rating in descending order? (Movies ko highest se lowest rating ke mutabiq sort karein).

# %%
# Convert IMDB rating to numeric
df['IMDB_Rating'] = pd.to_numeric(df['IMDB_Rating'], errors='coerce')

# Sort movies from highest to lowest rating
sorted_movies = df.sort_values(by='IMDB_Rating', ascending=False)

# Display result
print(sorted_movies)
# Out:
#                  Series_Title  Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption         1994.0           A  142 min
# 1               The Godfather         1972.0           A  175 min
# 2             The Dark Knight         2008.0          UA  152 min
# 3      The Godfather: Part II         1974.0           A  202 min
# 4                12 Angry Men         1957.0           U   96 min
# ..                        ...            ...         ...      ...
# 995    Breakfast at Tiffany's         1961.0           A  115 min
# 996                     Giant         1956.0           G  201 min
# 997     From Here to Eternity         1953.0      Passed  118 min
# 998                  Lifeboat         1944.0         NaN   97 min
# 999              The 39 Steps         1935.0         NaN   86 min
#
#                         Genre  IMDB_Rating  Meta_score              Director  \
# 0                       Drama          9.3        80.0        Frank Darabont
# ...

# %% [markdown]
# ### **Question 10**
# How can we sort all movies by the number of votes they received? (No_of_Votes ke mutabiq descending order mein sort karein).

# %%
# Convert No_of_Votes to numeric
df['No_of_Votes'] = pd.to_numeric(df['No_of_Votes'], errors='coerce')

# Sort movies by votes in descending order
sorted_votes = df.sort_values(by='No_of_Votes', ascending=False)

# Display result
print(sorted_votes)
# Out:
#                           Series_Title  Released_Year Certificate  Runtime  \
# 0             The Shawshank Redemption         1994.0           A  142 min
# 2                      The Dark Knight         2008.0          UA  152 min
# 8                            Inception         2010.0          UA  148 min
# 9                           Fight Club         1999.0           A  139 min
# 6                         Pulp Fiction         1994.0           A  154 min
# ..                                 ...            ...         ...      ...
# 570                              Raazi         2018.0          UA  138 min
# 718  Scarface: The Shame of the Nation         1932.0          PG   93 min
# 694                 La planète sauvage         1973.0           U   72 min
# 721                  God's Own Country         2017.0         NaN  104 min
# 264                     Ba wang bie ji         1993.0           R  171 min
#
# ...

# %% [markdown]
# ### **Question 11**
# Which movie has the longest runtime? (Sabse lambi movie ka naam aur runtime minutes mein nikalye).

# %%
print(df[['Runtime']].head(10))
# Out:
#    Runtime
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6      NaN
# 7      NaN
# 8      NaN
# 9      NaN

# %% [markdown]
# ### **Question 12**
# Which movies have Leonardo DiCaprio listed as the first star (Star1)?

# %%
# Filter movies where Star1 is Leonardo DiCaprio
leo_movies = df[df['Star1'] == 'Leonardo DiCaprio']

# Display result
print(leo_movies)
# Out:
#                          Series_Title  Released_Year Certificate  Runtime  \
# 8                           Inception         2010.0          UA      NaN
# 37                       The Departed         2006.0           A      NaN
# 145                    Shutter Island         2010.0           A      NaN
# 147           The Wolf of Wall Street         2013.0           A      NaN
# 243               Catch Me If You Can         2002.0           A      NaN
# 343                      The Revenant         2015.0           A      NaN
# 361                     Blood Diamond         2006.0           A      NaN
# 652                           Titanic         1997.0          UA      NaN
# 879  Once Upon a Time... in Hollywood         2019.0           A      NaN
#
#                           Genre  IMDB_Rating  Meta_score  \
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 37       Crime, Drama, Thriller          8.5        85.0
# ...

# %% [markdown]
# ### **Question 13**
# What is the average IMDB rating of all movies? (Saari movies ki average rating calculate karein).

# %%
# Calculate average IMDB rating of all movies
df['IMDB_Rating'] = pd.to_numeric(df['IMDB_Rating'], errors='coerce')

print("Average IMDB Rating:", df['IMDB_Rating'].mean())
# Out:
# Average IMDB Rating: 7.949299999999999

# %% [markdown]
# ### **Question 14**
# Dataset ka poora statistical summary (`describe()` function) display karein.

# %%
# Display complete statistical summary of dataset
print(df.describe())
# Out:
#        Released_Year  Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count     999.000000      0.0  1000.000000  843.000000  1.000000e+03
# mean     1991.217217      NaN     7.949300   77.971530  2.736929e+05
# std        23.297025      NaN     0.275491   12.376099  3.273727e+05
# min      1920.000000      NaN     7.600000   28.000000  2.508800e+04
# 25%      1976.000000      NaN     7.700000   70.000000  5.552625e+04
# 50%      1999.000000      NaN     7.900000   79.000000  1.385485e+05
# 75%      2009.000000      NaN     8.100000   87.000000  3.741612e+05
# max      2020.000000      NaN     9.300000  100.000000  2.343110e+06
#
#               Gross
# count  8.310000e+02
# mean   6.803475e+07
# std    1.097500e+08
# min    1.305000e+03
# 25%    3.253559e+06
# 50%    2.353089e+07
# 75%    8.075089e+07
# max    9.366622e+08

# %% [markdown]
# ### **Question 15**
# 'Runtime' column se 'min' text ko hata kar use proper integer (numeric) data type mein convert karein.

# %%
# Remove 'min' and convert Runtime to integer
df['Runtime'] = df['Runtime'].astype(str).str.replace(' min', '', regex=False)
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce').astype('Int64')

print(df['Runtime'])
# Out:
# 0      <NA>
# 1      <NA>
# 2      <NA>
# 3      <NA>
# 4      <NA>
#        ...
# 995    <NA>
# 996    <NA>
# 997    <NA>
# 998    <NA>
# 999    <NA>
# Name: Runtime, Length: 1000, dtype: Int64

# %% [markdown]
# ### **Question 16**
# 'Gross' column mein jo missing values (NaN) hain, unko pooray column ke median value se fill (impute) karein.

# %%
# Fill missing values in Gross column with median
df['Gross'] = df['Gross'].fillna(df['Gross'].median())

print(df['Gross'])
# Out:
# 0       28341469.0
# 1      134966411.0
# 2      534858444.0
# 3       57300000.0
# 4        4360000.0
#           ...
# 995     23530892.0
# 996     23530892.0
# 997     30500000.0
# 998     23530892.0
# 999     23530892.0
# Name: Gross, Length: 1000, dtype: float64

# %% [markdown]
# ### **Question 17**
# Har 'Certificate' category mein total kitni movies hain? (Value counts nikalye).

# %%
# Count total movies in each Certificate category
print(df['Certificate'].value_counts())
# Out:
# Certificate
# U           234
# A           197
# UA          175
# R           146
# PG-13        43
# PG           37
# Passed       34
# G            12
# Approved     11
# TV-PG         3
# GP            2
# TV-14         1
# 16            1
# TV-MA         1
# Unrated       1
# U/A           1
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 18**
# 'IMDB_Rating' aur 'Meta_score' ke darmiyan correlation coefficient maloom karein.

# %%
# Find correlation between IMDB_Rating and Meta_score
correlation = df['IMDB_Rating'].corr(df['Meta_score'])

print("Correlation Coefficient:", correlation)
# Out:
# Correlation Coefficient: 0.26853084455955506

# %% [markdown]
# ### **Question 19**
# Ek naya column banayein 'Rating_100_Scale' jisme 'IMDB_Rating' ko 10 se multiply kiya gaya ho.

# %%
# Create new column Rating_100_Scale
df['Rating_100_Scale'] = df['IMDB_Rating'] * 10

print(df[['IMDB_Rating', 'Rating_100_Scale']])
# Out:
#      IMDB_Rating  Rating_100_Scale
# 0            9.3              93.0
# 1            9.2              92.0
# 2            9.0              90.0
# 3            9.0              90.0
# 4            9.0              90.0
# ..           ...               ...
# 995          7.6              76.0
# 996          7.6              76.0
# 997          7.6              76.0
# 998          7.6              76.0
# 999          7.6              76.0
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### **Question 20**
# Year 1990 se 2000 (both inclusive) ke darmiyan release hone wali movies ki total count aur list nikaleyin.

# %%
# Movies released between 1990 and 2000 (inclusive)
movies_1990_2000 = df[(df['Released_Year'] >= 1990) & (df['Released_Year'] <= 2000)]

print("Total Movies:", movies_1990_2000.shape[0])
print(movies_1990_2000['Series_Title'])
# Out:
# Total Movies: 169
# 0      The Shawshank Redemption
# 6                  Pulp Fiction
# 7              Schindler's List
# 9                    Fight Club
# 11                 Forrest Gump
#                  ...
# 970             My Cousin Vinny
# 971           Omohide poro poro
# 972                Delicatessen
# 973                  Home Alone
# 974     The Godfather: Part III
# Name: Series_Title, Length: 169, dtype: str

# %% [markdown]
# ### **Question 21**
# (Visualization) IMDB_Rating ka distribution dekhne ke liye ek neat Histogram plot karein.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df['IMDB_Rating'], bins=10)

plt.title('IMDB Rating Distribution')
plt.xlabel('IMDB Rating')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### **Question 22**
# (Visualization) Top 10 Directors aur unki total movies ka ek attractive Bar Chart banayein.

# %%
top_directors = df['Director'].value_counts().head(10)

print(top_directors)

# Step 3: Plot attractive bar chart
plt.figure(figsize=(10, 6))
bars = plt.barh(top_directors.index[::-1], top_directors.values[::-1],
                 color="#4C72B0", edgecolor="black")

# Add value labels on bars
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height()/2,
              f'{int(width)}', va='center', fontsize=10, fontweight='bold')

plt.title("Top 10 Directors by Number of Movies", fontsize=14, fontweight='bold')
plt.xlabel("Number of Movies")
plt.ylabel("Director")
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()

plt.savefig("top_10_directors.png", dpi=300)
plt.show()
# Out:
# Director
# Alfred Hitchcock     14
# Steven Spielberg     13
# Hayao Miyazaki       11
# Martin Scorsese      10
# Akira Kurosawa       10
# Stanley Kubrick       9
# Billy Wilder          9
# Woody Allen           9
# Christopher Nolan     8
# Quentin Tarantino     8
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 23**
# (Visualization) IMDB_Rating aur Gross revenue ke darmiyan ek Scatter Plot banayein taake dono ka relation dikhe.

# %%
if df['Gross'].dtype == 'object':
    df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)

# Scatter plot
plt.figure(figsize=(9, 6))
plt.scatter(df['IMDB_Rating'], df['Gross'],
            color="#D85A30", alpha=0.6, edgecolor="black", s=50)

plt.title("IMDB Rating vs Gross Revenue", fontsize=14, fontweight='bold')
plt.xlabel("IMDB Rating")
plt.ylabel("Gross Revenue")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("rating_vs_gross_scatter.png", dpi=300)
plt.show()

# %% [markdown]
# ### **Question 24**
# (Visualization) Genres ka count dekhne ke liye top 5 genres ka ek clean Pie Chart banayein.

# %%
top_genres = df['Genre'].value_counts().head(5)

print(top_genres)

# Pie chart
plt.figure(figsize=(8, 8))
colors = ["#4C72B0", "#D85A30", "#55A868", "#C44E52", "#8172B2"]

plt.pie(top_genres.values, labels=top_genres.index, autopct='%1.1f%%',
        startangle=90, colors=colors,
        wedgeprops={'edgecolor': 'white', 'linewidth': 1.5},
        textprops={'fontsize': 11})

plt.title("Top 5 Genres Distribution", fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig("top_5_genres_pie.png", dpi=300)
plt.show()
# Out:
# Genre
# Drama                     85
# Drama, Romance            37
# Comedy, Drama             35
# Comedy, Drama, Romance    31
# Action, Crime, Drama      30
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 25**
# (Visualization) Meta_score ka distribution aur outliers check karne ke liye ek Box Plot banayein.

# %%
plt.figure(figsize=(6, 7))

plt.boxplot(df['Meta_score'].dropna(), vert=True, patch_artist=True,
            boxprops=dict(facecolor='#4C72B0', color='black'),
            medianprops=dict(color='red', linewidth=2),
            whiskerprops=dict(color='black'),
            capprops=dict(color='black'),
            flierprops=dict(marker='o', markerfacecolor='#D85A30', markersize=6))

plt.title('Meta Score Distribution and Outliers')
plt.ylabel('Meta Score')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Fahad Akram\AppData\Local\Temp\ipykernel_12992\479220014.py:3: MatplotlibDeprecationWarning: vert: bool was deprecated in Matplotlib 3.11 and will be removed in 3.13. Use orientation: {'vertical', 'horizontal'} instead.
#   plt.boxplot(df['Meta_score'].dropna(), vert=True, patch_artist=True,

# %% [markdown]
# ### **Question 26**
# (Visualization) Dataset mein 'Certificate' wise average 'Gross' kamai ka ek Bar Plot banayein.

# %%
df['Gross'] = pd.to_numeric(df['Gross'], errors='coerce')

# Drop missing values (optional but recommended)
df_clean = df.dropna(subset=['Certificate', 'Gross'])

# Group by Certificate and calculate average Gross
avg_gross = df_clean.groupby('Certificate')['Gross'].mean().sort_values(ascending=False)

# Plot
plt.figure(figsize=(10,6))
avg_gross.plot(kind='bar')

plt.title('Certificate vs Average Gross')
plt.xlabel('Certificate')
plt.ylabel('Average Gross')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Question 27**
# (Visualization) Har saal (Released_Year) kitni movies release hueen, iska ek Line Plot banayein.

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

# har saal kitni movies release hueen, unka count nikal rahe hain
movies_per_year = df['Released_Year'].value_counts().sort_index()

# ab line plot bana rahe hain
plt.figure(figsize=(11, 6))
plt.plot(movies_per_year.index, movies_per_year.values,
         color='#4C72B0', marker='o', markersize=3, linewidth=1.5)

plt.title('Number of Movies Released Per Year')
plt.xlabel('Released Year')
plt.ylabel('Number of Movies')
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Question 28**
# (Visualization) 'No_of_Votes' ke mutabiq top 5 highest voted movies ka ek Horizontal Bar Chart banayein.

# %%
if df['No_of_Votes'].dtype == 'object':
    df['No_of_Votes'] = df['No_of_Votes'].str.replace(',', '').astype(int)


top_voted = df[['Series_Title', 'No_of_Votes']].sort_values(by='No_of_Votes', ascending=False).head(5)

print(top_voted)


plt.figure(figsize=(9, 6))
bars = plt.barh(top_voted['Series_Title'][::-1], top_voted['No_of_Votes'][::-1],
                 color='#C44E52', edgecolor='black')


for bar in bars:
    width = bar.get_width()
    plt.text(width, bar.get_y() + bar.get_height()/2,
              f'{int(width):,}', va='center', ha='left', fontsize=9)

plt.title('Top 5 Highest Voted Movies')
plt.xlabel('Number of Votes')
plt.ylabel('Movie Title')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
#                Series_Title  No_of_Votes
# 0  The Shawshank Redemption      2343110
# 2           The Dark Knight      2303232
# 8                 Inception      2067042
# 9                Fight Club      1854740
# 6              Pulp Fiction      1826188

# %% [markdown]
# ### **Question 29**
# Har movie ke 'Genre' column ko split karke check karein ki total unique genres pure dataset mein kitne hain.

# %%
unique_genres = df['Genre'].str.split(', ').explode().unique()

print("Total unique genres:", len(unique_genres))
print(unique_genres)
# Out:
# Total unique genres: 21
# <StringArray>
# [    'Drama',     'Crime',    'Action', 'Adventure', 'Biography',   'History',
#     'Sci-Fi',   'Romance',   'Western',   'Fantasy',    'Comedy',  'Thriller',
#  'Animation',    'Family',       'War',   'Mystery',     'Music',    'Horror',
#    'Musical', 'Film-Noir',     'Sport']
# Length: 21, dtype: str

# %% [markdown]
# ### **Question 30**
# Dataset ko poora clean karne ke baad safely ek nayi csv file 'cleaned_movies.csv' ke naam se save karein.

# %%
df = df.drop_duplicates()

df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')


if df['Gross'].dtype == 'object':
    df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)

if df['No_of_Votes'].dtype == 'object':
    df['No_of_Votes'] = df['No_of_Votes'].str.replace(',', '').astype(int)

df = df.dropna(subset=['Released_Year', 'IMDB_Rating', 'Genre'])


df.to_csv("cleaned_movies.csv", index=False)

print("cleaned_movies.csv successfully save ho gayi")
print(df.shape)
# Out:
# cleaned_movies.csv successfully save ho gayi
# (999, 12)

# %% [markdown]
# ### **Question 31**
# Kaunsi movies hain jinki 'IMDB_Rating' 8.5 se zyada hai AUR unka 'Gross' revenue 100 million (100,000,000) se zyada hai? (Dual condition filter)

# %%
if df['Gross'].dtype == 'object':
    df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)

high_rated_high_gross = df[(df['IMDB_Rating'] > 8.5) & (df['Gross'] > 100000000)]

print(high_rated_high_gross[['Series_Title', 'IMDB_Rating', 'Gross']])
# Out:
#                                          Series_Title  IMDB_Rating  \
# 1                                       The Godfather          9.2
# 2                                     The Dark Knight          9.0
# 5       The Lord of the Rings: The Return of the King          8.9
# 6                                        Pulp Fiction          8.9
# 8                                           Inception          8.8
# 10  The Lord of the Rings: The Fellowship of the Ring          8.8
# 11                                       Forrest Gump          8.8
# 13              The Lord of the Rings: The Two Towers          8.7
# 14                                         The Matrix          8.7
# 16     Star Wars: Episode V - The Empire Strikes Back          8.7
# 17                    One Flew Over the Cuckoo's Nest          8.7
# 21                                       Interstellar          8.6
# 24                                Saving Private Ryan          8.6
# ...

# %% [markdown]
# ### **Question 32**
# Director 'Christopher Nolan' ki un movies ke naam aur release year nikalein jinka 'Runtime' 140 minutes se zyada hai.

# %%
# Runtime ko clean kar rahe hain, missing values ko NaN hi rehne dete hain
df['Runtime'] = df['Runtime'].astype(str).str.replace(' min', '', regex=False)
df['Runtime'] = pd.to_numeric(df['Runtime'], errors='coerce')

# ab missing Runtime wali rows ko drop kar sakte hain (filter se pehle)
df = df.dropna(subset=['Runtime'])

nolan_movies = df[(df['Director'] == 'Christopher Nolan') & (df['Runtime'] > 140)]

print(nolan_movies[['Series_Title', 'Released_Year', 'Runtime']])
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Runtime]
# Index: []

# %% [markdown]
# ### **Question 33**
# Aise actors (Star1) ki list nikalein jinhone 'Action' ya 'Sci-Fi' genre mein kaam kiya hai AUR unki movies ki 'IMDB_Rating' kam az kam 8.0 hai.

# %%
filtered = df[
    (df['Genre'].str.contains('Action|Sci-Fi', case=False, na=False)) &
    (df['IMDB_Rating'] >= 8.0)
]


action_scifi_actors = filtered['Star1'].unique()

print("Total actors:", len(action_scifi_actors))
print(action_scifi_actors)
# Out:
# Total actors: 72
# <StringArray>
# [       'Christian Bale',           'Elijah Wood',     'Leonardo DiCaprio',
#        'Lilly Wachowski',           'Mark Hamill',   'Matthew McConaughey',
#        'Tatsuya Nakadai',        'Toshirô Mifune',         'Russell Crowe',
#              'Jean Reno', 'Arnold Schwarzenegger',        'Michael J. Fox',
#                'Pushkar',            'Aamir Khan',          'Peter Ramsey',
#              'Joe Russo',          'Choi Min-sik',          'Yôji Matsuda',
#          'Harrison Ford',      'Sigourney Weaver',            'Jim Carrey',
#       'Malcolm McDowell',           'Keir Dullea',         'Brigitte Helm',
#          'Vicky Kaushal',                  'Yash',               'Prabhas',
#         'Manoj Bajpayee',           'Irrfan Khan',             'Tom Hardy',
#           'Hugo Weaving',          'Akshay Kumar',         'Jason Flemyng',
#           'Bruce Willis',      'Alisa Freyndlikh',         'Sanjeev Kumar',
# ...

# %% [markdown]
# ### **Question 34**
# Year 2010 se 2020 ke darmiyan release hone wali un movies ka data filter karein jinko Certificate 'UA' ya 'A' mila hai.

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

filtered = df[
    (df['Released_Year'] >= 2010) & (df['Released_Year'] <= 2020) &
    (df['Certificate'].isin(['UA', 'A']))
]

print(filtered[['Series_Title', 'Released_Year', 'Certificate']])
# Out:
#                        Series_Title  Released_Year Certificate
# 8                         Inception         2010.0          UA
# 19                     Gisaengchung         2019.0           A
# 21                     Interstellar         2014.0          UA
# 33                            Joker         2019.0           A
# 34                         Whiplash         2014.0           A
# ..                              ...            ...         ...
# 898  Dawn of the Planet of the Apes         2014.0          UA
# 900                    Serbuan maut         2011.0           A
# 901                    End of Watch         2012.0           A
# 903                  A Star Is Born         2018.0          UA
# 908                        Kick-Ass         2010.0          UA
#
# [131 rows x 3 columns]

# %% [markdown]
# ### **Question 35**
# Dataset mein 'Meta_score' 90 se zyada aur 'IMDB_Rating' 8.5 se kam wali unique movies kaunsi hain?

# %%
filtered = df[(df['Meta_score'] > 90) & (df['IMDB_Rating'] < 8.5)]

unique_movies = filtered['Series_Title'].unique()

print("Total unique movies:", len(unique_movies))
print(filtered[['Series_Title', 'Meta_score', 'IMDB_Rating']])
# Out:
# Total unique movies: 117
#                                           Series_Title  Meta_score  \
# 66                                              WALL·E        95.0
# 74                                      Apocalypse Now        94.0
# 78   Dr. Strangelove or: How I Learned to Stop Worr...        97.0
# 81                                         Rear Window       100.0
# 89                             Jodaeiye Nader az Simin        95.0
# ..                                                 ...         ...
# 875                                           Fantasia        96.0
# 881                                The Florida Project        92.0
# 895                                           Leviafan        92.0
# 994                                 A Hard Day's Night        96.0
# 999                                       The 39 Steps        93.0
#
#      IMDB_Rating
# 66           8.4
# 74           8.4
# 78           8.4
# 81           8.4
# 89           8.3
# ..           ...
# ...

# %% [markdown]
# ### **Question 36**
# (Visualization) 'Drama' aur 'Action' genres ki movies ke 'Gross' revenue ko compare karne ke liye ek Grouped Box Plot ya Violin Plot banayein.

# %%
if df['Gross'].dtype == 'object':
    df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)

drama_movies = df[df['Genre'].str.contains('Drama', na=False)]['Gross'].dropna()
action_movies = df[df['Genre'].str.contains('Action', na=False)]['Gross'].dropna()

plt.figure(figsize=(8, 6))
plt.violinplot([drama_movies, action_movies], showmedians=True)

plt.xticks([1, 2], ['Drama', 'Action'])
plt.title('Gross Revenue Comparison: Drama vs Action')
plt.ylabel('Gross Revenue')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Question 37**
# Har Director ki un movies ka count maloom karein jinhone 'No_of_Votes' 500,000 (5 lakh) se zyada hasil kiye hain.

# %%
if df['No_of_Votes'].dtype == 'object':
    df['No_of_Votes'] = df['No_of_Votes'].str.replace(',', '').astype(int)

high_vote_movies = df[df['No_of_Votes'] > 500000]

director_counts = high_vote_movies['Director'].value_counts()

print(director_counts)
# Out:
# Director
# Christopher Nolan    8
# Quentin Tarantino    8
# Steven Spielberg     8
# Peter Jackson        5
# David Fincher        5
#                     ..
# Mike Newell          1
# Steven Soderbergh    1
# Pierre Coffin        1
# Ruben Fleischer      1
# Chris Columbus       1
# Name: count, Length: 107, dtype: int64

# %% [markdown]
# ### **Question 38**
# Un movies ke naam aur ratings batayein jinka 'Released_Year' 2000 se pehle ka hai AUR unka 'Gross' unke overall median gross se zyada hai.

# %%
df['Released_Year'] = pd.to_numeric(df['Released_Year'], errors='coerce')

if df['Gross'].dtype == 'object':
    df['Gross'] = df['Gross'].str.replace(',', '').str.replace('$', '').astype(float)

overall_median_gross = df['Gross'].median()

filtered = df[(df['Released_Year'] < 2000) & (df['Gross'] > overall_median_gross)]

print(filtered[['Series_Title', 'IMDB_Rating', 'Released_Year', 'Gross']])
# Out:
#                            Series_Title  IMDB_Rating  Released_Year  \
# 0              The Shawshank Redemption          9.3         1994.0
# 1                         The Godfather          9.2         1972.0
# 3                The Godfather: Part II          9.0         1974.0
# 6                          Pulp Fiction          8.9         1994.0
# 7                      Schindler's List          8.9         1993.0
# ..                                  ...          ...            ...
# 985                Escape from Alcatraz          7.6         1979.0
# 987                    Midnight Express          7.6         1978.0
# 988  Close Encounters of the Third Kind          7.6         1977.0
# 992                     The Jungle Book          7.6         1967.0
# 997               From Here to Eternity          7.6         1953.0
#
#            Gross
# 0     28341469.0
# 1    134966411.0
# 3     57300000.0
# 6    107928762.0
# 7     96898818.0
# ..           ...
# 985   43000000.0
# ...

# %% [markdown]
# ### **Question 39**
# Aisi movies ka data nikalein jahan 'Star1' (Main Actor) aur 'Director' dono bilkul same person hain.

# %%
same_person = df[df['Star1'] == df['Director']]

print(same_person[['Series_Title', 'Director', 'Star1']])
# Out:
#                               Series_Title               Director  \
# 26                         La vita è bella        Roberto Benigni
# 51                            Modern Times        Charles Chaplin
# 52                             City Lights        Charles Chaplin
# 83                      The Great Dictator        Charles Chaplin
# 102                             Braveheart             Mel Gibson
# 124                           Citizen Kane           Orson Welles
# 127                                The Kid        Charles Chaplin
# 167                             Unforgiven         Clint Eastwood
# 193                          The Gold Rush        Charles Chaplin
# 194                           Sherlock Jr.          Buster Keaton
# 225                            Gran Torino         Clint Eastwood
# 318                             The Circus        Charles Chaplin
# 371  Bom Yeoareum Gaeul Gyeoul Geurigo Bom             Ki-duk Kim
# ...

# %% [markdown]
# ### **Question 40**
# (Visualization) Top 5 highest rated movies aur unke 'Meta_score' vs 'IMDB_Rating' (scaled to 100) ka ek Side-by-Side Comparison Bar Chart banayein.

# %%
df = df.dropna(subset=['Meta_score', 'IMDB_Rating'])

top5 = df.sort_values(by='IMDB_Rating', ascending=False).head(5).reset_index(drop=True)


top5['IMDB_Scaled'] = top5['IMDB_Rating'] * 10

x = np.arange(len(top5))
width = 0.35

plt.figure(figsize=(10, 6))

plt.bar(x - width/2, top5['Meta_score'], width, label='Meta Score', color='#4C72B0')
plt.bar(x + width/2, top5['IMDB_Scaled'], width, label='IMDB Rating (scaled)', color='#D85A30')

plt.xticks(x, top5['Series_Title'], rotation=30, ha='right')
plt.ylabel('Score (out of 100)')
plt.title('Meta Score vs IMDB Rating (Scaled) - Top 5 Movies')
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()
